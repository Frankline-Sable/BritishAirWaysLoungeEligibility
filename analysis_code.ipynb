# %%
print("British Airways Lounge Eligibility")
# Out:
# British Airways Lounge Eligibility

# %%
import pandas

df=pandas.read_excel("British Airways Summer Schedule Dataset - Forage Data Science Task 1.xlsx")

# %%
df.shape
# Out:
# (10000, 17)

# %%
df.head(3)
# Out:
#   FLIGHT_DATE FLIGHT_TIME TIME_OF_DAY AIRLINE_CD FLIGHT_NO  \
# 0  2025-09-02    14:19:00   Afternoon         BA    BA5211
# 1  2025-06-10    06:42:00     Morning         BA    BA7282
# 2  2025-10-27    15:33:00   Afternoon         BA    BA1896
#
#   DEPARTURE_STATION_CD ARRIVAL_STATION_CD ARRIVAL_COUNTRY ARRIVAL_REGION  \
# 0                  LHR                LAX             USA  North America
# 1                  LHR                LAX             USA  North America
# 2                  LHR                FRA         Germany         Europe
#
#     HAUL AIRCRAFT_TYPE  FIRST_CLASS_SEATS  BUSINESS_CLASS_SEATS  \
# 0   LONG          B777                  8                    49
# 1   LONG          B777                  8                    49
# 2  SHORT          A320                  0                    17
#
#    ECONOMY_SEATS  TIER1_ELIGIBLE_PAX  TIER2_ELIGIBLE_PAX  TIER3_ELIGIBLE_PAX
# 0            178                   0                  10                  38
# ...

# %%
df.columns
# Out:
# Index(['FLIGHT_DATE', 'FLIGHT_TIME', 'TIME_OF_DAY', 'AIRLINE_CD', 'FLIGHT_NO',
#        'DEPARTURE_STATION_CD', 'ARRIVAL_STATION_CD', 'ARRIVAL_COUNTRY',
#        'ARRIVAL_REGION', 'HAUL', 'AIRCRAFT_TYPE', 'FIRST_CLASS_SEATS',
#        'BUSINESS_CLASS_SEATS', 'ECONOMY_SEATS', 'TIER1_ELIGIBLE_PAX',
#        'TIER2_ELIGIBLE_PAX', 'TIER3_ELIGIBLE_PAX'],
#       dtype='str')

# %%
for clm in df.columns:
    print(f"{clm} : {df[clm].value_counts()}\n--------------------------------")
# Out:
# FLIGHT_DATE : FLIGHT_DATE
# 2025-06-05    68
# 2025-08-16    68
# 2025-06-15    66
# 2025-04-25    66
# 2025-05-02    65
#               ..
# 2025-10-19    33
# 2025-04-19    32
# 2025-05-09    31
# 2025-10-18    30
# 2025-05-03    29
# Name: count, Length: 210, dtype: int64
# --------------------------------
# FLIGHT_TIME : FLIGHT_TIME
# 16:49:00    20
# 17:24:00    20
# 10:42:00    19
# 20:23:00    19
# 09:48:00    19
#             ..
# 07:21:00     2
# 14:08:00     2
# 15:56:00     2
# 11:24:00     2
# 22:49:00     1
# Name: count, Length: 1020, dtype: int64
# --------------------------------
# TIME_OF_DAY : TIME_OF_DAY
# Morning      3530
# Evening      2973
# Afternoon    2305
# Lunchtime    1192
# Name: count, dtype: int64
# --------------------------------
# AIRLINE_CD : AIRLINE_CD
# BA    10000
# Name: count, dtype: int64
# --------------------------------
# FLIGHT_NO : FLIGHT_NO
# BA8347    7
# BA5934    7
# BA5015    6
# BA7761    6
# BA6477    6
#          ..
# ...

# %%
for clm in df.columns:
    print(f"{clm} : {df[clm].unique()}\n-------------------------------")
# Out:
# FLIGHT_DATE : <DatetimeArray>
# ['2025-09-02 00:00:00', '2025-06-10 00:00:00', '2025-10-27 00:00:00',
#  '2025-06-15 00:00:00', '2025-08-25 00:00:00', '2025-07-12 00:00:00',
#  '2025-09-16 00:00:00', '2025-04-24 00:00:00', '2025-05-17 00:00:00',
#  '2025-05-01 00:00:00',
#  ...
#  '2025-07-10 00:00:00', '2025-07-23 00:00:00', '2025-04-19 00:00:00',
#  '2025-08-26 00:00:00', '2025-10-07 00:00:00', '2025-09-18 00:00:00',
#  '2025-09-24 00:00:00', '2025-06-09 00:00:00', '2025-08-07 00:00:00',
#  '2025-10-23 00:00:00']
# Length: 210, dtype: datetime64[us]
# -------------------------------
# FLIGHT_TIME : [datetime.time(14, 19) datetime.time(6, 42) datetime.time(15, 33) ...
#  datetime.time(17, 38) datetime.time(11, 52) datetime.time(11, 24)]
# -------------------------------
# TIME_OF_DAY : <StringArray>
# ['Afternoon', 'Morning', 'Evening', 'Lunchtime']
# Length: 4, dtype: str
# -------------------------------
# AIRLINE_CD : <StringArray>
# ['BA']
# Length: 1, dtype: str
# ...

# %%
filteredCategory =df[(df["ARRIVAL_REGION"]=='North America') & (df['HAUL']=="LONG")]
filteredCategory.head()
# Out:
#    FLIGHT_DATE FLIGHT_TIME TIME_OF_DAY AIRLINE_CD FLIGHT_NO  \
# 0   2025-09-02    14:19:00   Afternoon         BA    BA5211
# 1   2025-06-10    06:42:00     Morning         BA    BA7282
# 7   2025-04-24    14:50:00   Afternoon         BA    BA7116
# 11  2025-09-02    07:48:00     Morning         BA    BA8942
# 16  2025-04-02    17:04:00   Afternoon         BA    BA8677
#
#    DEPARTURE_STATION_CD ARRIVAL_STATION_CD ARRIVAL_COUNTRY ARRIVAL_REGION  \
# 0                   LHR                LAX             USA  North America
# 1                   LHR                LAX             USA  North America
# 7                   LHR                ORD             USA  North America
# 11                  LHR                LAX             USA  North America
# 16                  LHR                ORD             USA  North America
#
#     HAUL AIRCRAFT_TYPE  FIRST_CLASS_SEATS  BUSINESS_CLASS_SEATS  \
# 0   LONG          B777                  8                    49
# ...

# %%
filteredCategory =df[(df["ARRIVAL_REGION"]=='North America') & (df['HAUL']=="LONG")]
totalSeats=filteredCategory['FIRST_CLASS_SEATS'].sum()+filteredCategory['BUSINESS_CLASS_SEATS'].sum()+filteredCategory['ECONOMY_SEATS'].sum()
tier1El=(filteredCategory['FIRST_CLASS_SEATS'].sum()/totalSeats)*100
tier2El=(filteredCategory['BUSINESS_CLASS_SEATS'].sum()/totalSeats)*100
tier3El=(filteredCategory['ECONOMY_SEATS'].sum()/totalSeats)*100
print(f"Total Seats: {totalSeats}\n Tier 1, 2 & 3: {tier1El}, {tier2El}, {tier3El}")
# Out:
# Total Seats: 776567
#  Tier 1, 2 & 3: 1.324547656544767, 16.29080298287205, 82.38464936058318

# %%
filteredCategory =df[(df["ARRIVAL_REGION"]=='Europe') & (df['HAUL']=="SHORT")]
totalSeats=filteredCategory['FIRST_CLASS_SEATS'].sum()+filteredCategory['BUSINESS_CLASS_SEATS'].sum()+filteredCategory['ECONOMY_SEATS'].sum()
tier1El=(filteredCategory['FIRST_CLASS_SEATS'].sum()/totalSeats)*100
tier2El=(filteredCategory['BUSINESS_CLASS_SEATS'].sum()/totalSeats)*100
tier3El=(filteredCategory['ECONOMY_SEATS'].sum()/totalSeats)*100
print(f"Total Seats: {totalSeats}\n Tier 1, 2 & 3: {tier1El}, {tier2El}, {tier3El}")
# Out:
# Total Seats: 1075500
#  Tier 1, 2 & 3: 0.0, 5.571920037192004, 94.428079962808

# %%
filteredCategory =df[(df["ARRIVAL_REGION"]=='Asia') & (df['HAUL']=="LONG")]
totalSeats=filteredCategory['FIRST_CLASS_SEATS'].sum()+filteredCategory['BUSINESS_CLASS_SEATS'].sum()+filteredCategory['ECONOMY_SEATS'].sum()
tier1El=(filteredCategory['FIRST_CLASS_SEATS'].sum()/totalSeats)*100
tier2El=(filteredCategory['BUSINESS_CLASS_SEATS'].sum()/totalSeats)*100
tier3El=(filteredCategory['ECONOMY_SEATS'].sum()/totalSeats)*100
print(f"Total Seats: {totalSeats}\n Tier 1, 2 & 3: {tier1El}, {tier2El}, {tier3El}")
# Out:
# Total Seats: 197355
#  Tier 1, 2 & 3: 1.305262091155532, 16.248891591294875, 82.4458463175496

# %%
filteredCategory =df[(df["ARRIVAL_REGION"]=='Middle East') & (df['HAUL']=="LONG")]
totalSeats=filteredCategory['FIRST_CLASS_SEATS'].sum()+filteredCategory['BUSINESS_CLASS_SEATS'].sum()+filteredCategory['ECONOMY_SEATS'].sum()
tier1El=(filteredCategory['FIRST_CLASS_SEATS'].sum()/totalSeats)*100
tier2El=(filteredCategory['BUSINESS_CLASS_SEATS'].sum()/totalSeats)*100
tier3El=(filteredCategory['ECONOMY_SEATS'].sum()/totalSeats)*100
print(f"Total Seats: {totalSeats}\n Tier 1, 2 & 3: {tier1El}, {tier2El}, {tier3El}")
# Out:
# Total Seats: 200647
#  Tier 1, 2 & 3: 1.3007919380803101, 16.06552801686544, 82.63368004505425

# %% [markdown]
# [[Finding the representative samples ]]

# %%
filteredCategory =df[(df["ARRIVAL_REGION"]=='North America') & (df['HAUL']=="LONG")].head(5)
totalSeats=[filteredCategory['FIRST_CLASS_SEATS'].sum(),filteredCategory['BUSINESS_CLASS_SEATS'].sum(),filteredCategory['ECONOMY_SEATS'].sum()]
tier1El=(filteredCategory['FIRST_CLASS_SEATS'].sum()/sum(totalSeats))*100
tier2El=(filteredCategory['BUSINESS_CLASS_SEATS'].sum()/sum(totalSeats))*100
tier3El=(filteredCategory['ECONOMY_SEATS'].sum()/sum(totalSeats))*100
print(f"{sum(totalSeats)}, {tier1El}, {totalSeats[0]}, {tier2El}, {totalSeats[1]}, {tier3El}, {totalSeats[2]}")
# Out:
# 1252, 2.5559105431309903, 32, 19.568690095846645, 245, 77.87539936102237, 975

# %%
filteredCategory =df[(df["ARRIVAL_REGION"]=='Europe') & (df['HAUL']=="SHORT")].head(5)
totalSeats=[filteredCategory['FIRST_CLASS_SEATS'].sum(),filteredCategory['BUSINESS_CLASS_SEATS'].sum(),filteredCategory['ECONOMY_SEATS'].sum()]
tier1El=(filteredCategory['FIRST_CLASS_SEATS'].sum()/sum(totalSeats))*100
tier2El=(filteredCategory['BUSINESS_CLASS_SEATS'].sum()/sum(totalSeats))*100
tier3El=(filteredCategory['ECONOMY_SEATS'].sum()/sum(totalSeats))*100
print(f"{sum(totalSeats)}, {tier1El}, {totalSeats[0]}, {tier2El}, {totalSeats[1]}, {tier3El}, {totalSeats[2]}")
# Out:
# 900, 0.0, 0, 8.666666666666668, 78, 91.33333333333333, 822

# %%
filteredCategory =df[(df["ARRIVAL_REGION"]=='Asia') & (df['HAUL']=="LONG")].head(5)
totalSeats=[filteredCategory['FIRST_CLASS_SEATS'].sum(),filteredCategory['BUSINESS_CLASS_SEATS'].sum(),filteredCategory['ECONOMY_SEATS'].sum()]
tier1El=(filteredCategory['FIRST_CLASS_SEATS'].sum()/sum(totalSeats))*100
tier2El=(filteredCategory['BUSINESS_CLASS_SEATS'].sum()/sum(totalSeats))*100
tier3El=(filteredCategory['ECONOMY_SEATS'].sum()/sum(totalSeats))*100
print(f"{sum(totalSeats)}, {tier1El}, {totalSeats[0]}, {tier2El}, {totalSeats[1]}, {tier3El}, {totalSeats[2]}")
# Out:
# 1607, 1.3690105787181084, 22, 15.183571873055381, 244, 83.44741754822651, 1341

# %%
filteredCategory =df[(df["ARRIVAL_REGION"]=='Middle East') & (df['HAUL']=="LONG")].head(5)
totalSeats=[filteredCategory['FIRST_CLASS_SEATS'].sum(),filteredCategory['BUSINESS_CLASS_SEATS'].sum(),filteredCategory['ECONOMY_SEATS'].sum()]
tier1El=(filteredCategory['FIRST_CLASS_SEATS'].sum()/sum(totalSeats))*100
tier2El=(filteredCategory['BUSINESS_CLASS_SEATS'].sum()/sum(totalSeats))*100
tier3El=(filteredCategory['ECONOMY_SEATS'].sum()/sum(totalSeats))*100
print(f"{sum(totalSeats)}, {tier1El}, {totalSeats[0]}, {tier2El}, {totalSeats[1]}, {tier3El}, {totalSeats[2]}")
# Out:
# 1238, 3.231017770597738, 40, 19.547657512116317, 242, 77.22132471728594, 956

# %% [markdown]
# [[ Grouping by flights ]]

# %%
filteredCategory =df[(df["ARRIVAL_REGION"]=='North America') & (df['HAUL']=="LONG")]

filteredCategory.head(5)
# Out:
#    FLIGHT_DATE FLIGHT_TIME TIME_OF_DAY AIRLINE_CD FLIGHT_NO  \
# 0   2025-09-02    14:19:00   Afternoon         BA    BA5211
# 1   2025-06-10    06:42:00     Morning         BA    BA7282
# 7   2025-04-24    14:50:00   Afternoon         BA    BA7116
# 11  2025-09-02    07:48:00     Morning         BA    BA8942
# 16  2025-04-02    17:04:00   Afternoon         BA    BA8677
#
#    DEPARTURE_STATION_CD ARRIVAL_STATION_CD ARRIVAL_COUNTRY ARRIVAL_REGION  \
# 0                   LHR                LAX             USA  North America
# 1                   LHR                LAX             USA  North America
# 7                   LHR                ORD             USA  North America
# 11                  LHR                LAX             USA  North America
# 16                  LHR                ORD             USA  North America
#
#     HAUL AIRCRAFT_TYPE  FIRST_CLASS_SEATS  BUSINESS_CLASS_SEATS  \
# 0   LONG          B777                  8                    49
# ...
